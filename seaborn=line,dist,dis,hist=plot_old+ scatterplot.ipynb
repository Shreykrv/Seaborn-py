# %%
import seaborn as sns
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('penguins.csv')

# %%
df
# Out:
#      Unnamed: 0    species     island  bill_length_mm  bill_depth_mm  \
# 0             1     Adelie  Torgersen            39.1           18.7
# 1             2     Adelie  Torgersen            39.5           17.4
# 2             3     Adelie  Torgersen            40.3           18.0
# 3             4     Adelie  Torgersen             NaN            NaN
# 4             5     Adelie  Torgersen            36.7           19.3
# ..          ...        ...        ...             ...            ...
# 339         340  Chinstrap      Dream            55.8           19.8
# 340         341  Chinstrap      Dream            43.5           18.1
# 341         342  Chinstrap      Dream            49.6           18.2
# 342         343  Chinstrap      Dream            50.8           19.0
# 343         344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# ...

# %%
df.head(1)
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
#
#    flipper_length_mm  body_mass_g   sex  year
# 0              181.0       3750.0  male  2007

# %%
sns.lineplot(x='bill_length_mm',y='bill_depth_mm', hue='island',data=df,size=50,style='island',palette='cool',
             markers=['o','*','>'],dashes = False, legend = False)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.lineplot(x='bill_length_mm',y='bill_depth_mm', hue='island',data=df,style='island',palette='cool',
             markers=['o','*','>'],dashes = False, legend = 'full')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.distplot(df['bill_length_mm'],kde= True)
# Out:
# C:\Users\Shrey Kumar\AppData\Local\Temp\ipykernel_15784\2261633885.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bill_length_mm'],kde= True)
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.histplot(df['bill_length_mm'])
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
df3.head(2)
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007

# %%
sns.displot(df['bill_length_mm'],kde= True , bins = [30,35,40,45,50],rug=True)

# %%
sns.displot(df['bill_length_mm'],kde= True , bins = [30,35,40,45,50],rug=True, color ='m',log_scale = True)

# %%
sns.scatterplot(df['sex'])
# Out:
# <Axes: ylabel='sex'>

# %%
sns.scatterplot(df['bill_length_mm'],df['bill_length_mm'] )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.scatterplot(df['bill_length_mm'],df['bill_length_mm'] )
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.scatterplot(x='bill_length_mm',y='bill_depth_mm', hue='island',data=df,style='island',palette='cool',
             markers=['o','*','>'],dashes = False, legend = 'full')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\collections.py:618, in Collection.set_linestyle(self, ls)
#     617 try:
# --> 618     dashes = [mlines._get_dash_pattern(ls)]
#     619 except ValueError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\lines.py:52, in _get_dash_pattern(style)
#      51 else:
# ---> 52     raise ValueError(f'Unrecognized linestyle: {style!r}')
#      54 # normalize offset to be positive and shorter than the dash cycle
#
# ValueError: Unrecognized linestyle: False
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ...
